# %% [markdown]
# # PYTHON TOKENIZER

# %%
import tokenize
import keyword
import builtins




def is_valid_identifier(identifier):
    """
    Function to check if an identifier follows Python's identifier declaration rules.
    """
    return identifier.isidentifier() and identifier not in keyword.kwlist

def tokenize_source_code(file_path):
    with open(file_path, 'rb') as f:
        tokens = tokenize.tokenize(f.readline)
        current_line = 1
        operators_list = ['+', '-', '*', '/', '//', '%', '**', '==', '!=', '>', '<', '>=', '<=', 'and', 'or', 'not', '&', '|', '^', '~', '<<', '>>', '=', '+=', '-=', '*=', '/=', '%=', '//=', '**=', '&=', '|=', '^=', '<<=', '>>=']

        for token in tokens:
            if token.type == tokenize.NEWLINE:
                current_line += 1
            else:
                lexeme = token.string
                token_type = tokenize.tok_name[token.type]
                line_number = current_line

                # Categorize tokens based on their types
                if token_type == 'NAME':
                    if lexeme in builtins.__dict__:
                        token_category = 'Built-in Type or Function'
                   
                    elif is_valid_identifier(lexeme):
                        token_category = 'Identifier'
                    else:
                        token_category = 'Keyword'
                elif token_type == 'NUMBER':
                    token_category = 'Number'
                elif token_type == 'STRING':
                    token_category = 'String'
                elif token_type == 'OP' and lexeme in operators_list :
                    token_category = 'Operator'
                elif token_type == 'OP':
                    token_category = ' punctuator'
                elif token_type == 'NEWLINE':
                    token_category = 'Newline'
                else:
                    token_category = 'Other'
                
                # Print token information along with its category
                print(f"| {lexeme:<30} |  {token_type:<10} | {token_category:<40} | {line_number:<10} |")

# Example usage:
file_path = 'TEST.py'  # Replace 'TEST.py' with your source code file path
tokenize_source_code(file_path)
# Out:
# | utf-8                          |  ENCODING   | Other                                    | 1          |
# | def                            |  NAME       | Keyword                                  | 1          |
# | factorial                      |  NAME       | Identifier                               | 1          |
# | (                              |  OP         |  punctuator                              | 1          |
# | n                              |  NAME       | Identifier                               | 1          |
# | )                              |  OP         |  punctuator                              | 1          |
# | :                              |  OP         |  punctuator                              | 1          |
# |                                |  INDENT     | Other                                    | 2          |
# | if                             |  NAME       | Keyword                                  | 2          |
# | n                              |  NAME       | Identifier                               | 2          |
# | ==                             |  OP         | Operator                                 | 2          |
# | 0                              |  NUMBER     | Number                                   | 2          |
# | :                              |  OP         |  punctuator                              | 2          |
# |                                |  INDENT     | Other                                    | 3          |
# | return                         |  NAME       | Keyword                                  | 3          |
# | 1                              |  NUMBER     | Number                                   | 3          |
# |                                |  DEDENT     | Other                                    | 4          |
# | else                           |  NAME       | Keyword                                  | 4          |
# | :                              |  OP         |  punctuator                              | 4          |
# |                                |  INDENT     | Other                                    | 5          |
# | return                         |  NAME       | Keyword                                  | 5          |
# | n                              |  NAME       | Identifier                               | 5          |
# | *                              |  OP         | Operator                                 | 5          |
# | factorial                      |  NAME       | Identifier                               | 5          |
# | (                              |  OP         |  punctuator                              | 5          |
# | n                              |  NAME       | Identifier                               | 5          |
# | -                              |  OP         | Operator                                 | 5          |
# | 1                              |  NUMBER     | Number                                   | 5          |
# | )                              |  OP         |  punctuator                              | 5          |
# |
#                               |  NL         | Other                                    | 6          |
# |                                |  DEDENT     | Other                                    | 6          |
# |                                |  DEDENT     | Other                                    | 6          |
# | number                         |  NAME       | Identifier                               | 6          |
# | =                              |  OP         | Operator                                 | 6          |
# | int                            |  NAME       | Built-in Type or Function                | 6          |
# | (                              |  OP         |  punctuator                              | 6          |
# | input                          |  NAME       | Built-in Type or Function                | 6          |
# | (                              |  OP         |  punctuator                              | 6          |
# | "Enter a number to find its factorial: " |  STRING     | String                                   | 6          |
# | )                              |  OP         |  punctuator                              | 6          |
# | )                              |  OP         |  punctuator                              | 6          |
# | result                         |  NAME       | Identifier                               | 7          |
# | =                              |  OP         | Operator                                 | 7          |
# | factorial                      |  NAME       | Identifier                               | 7          |
# | (                              |  OP         |  punctuator                              | 7          |
# | number                         |  NAME       | Identifier                               | 7          |
# | )                              |  OP         |  punctuator                              | 7          |
# | print                          |  NAME       | Built-in Type or Function                | 8          |
# | (                              |  OP         |  punctuator                              | 8          |
# | "Factorial of"                 |  STRING     | String                                   | 8          |
# | ,                              |  OP         |  punctuator                              | 8          |
# | number                         |  NAME       | Identifier                               | 8          |
# | ,                              |  OP         |  punctuator                              | 8          |
# | "is"                           |  STRING     | String                                   | 8          |
# | ,                              |  OP         |  punctuator                              | 8          |
# | result                         |  NAME       | Identifier                               | 8          |
# | )                              |  OP         |  punctuator                              | 8          |
# |
#                               |  NL         | Other                                    | 9          |
# |
#                               |  NL         | Other                                    | 9          |
# | #CALCULATING DISCOUNT          |  COMMENT    | Other                                    | 9          |
# |
#                               |  NL         | Other                                    | 9          |
# | def                            |  NAME       | Keyword                                  | 9          |
# | calculate_discount             |  NAME       | Identifier                               | 9          |
# | (                              |  OP         |  punctuator                              | 9          |
# | price                          |  NAME       | Identifier                               | 9          |
# | ,                              |  OP         |  punctuator                              | 9          |
# | discount_percentage            |  NAME       | Identifier                               | 9          |
# | )                              |  OP         |  punctuator                              | 9          |
# | :                              |  OP         |  punctuator                              | 9          |
# |                                |  INDENT     | Other                                    | 10         |
# | discount_amount                |  NAME       | Identifier                               | 10         |
# | =                              |  OP         | Operator                                 | 10         |
# | price                          |  NAME       | Identifier                               | 10         |
# | *                              |  OP         | Operator                                 | 10         |
# | (                              |  OP         |  punctuator                              | 10         |
# | discount_percentage            |  NAME       | Identifier                               | 10         |
# | /                              |  OP         | Operator                                 | 10         |
# | 100                            |  NUMBER     | Number                                   | 10         |
# | )                              |  OP         |  punctuator                              | 10         |
# | discounted_price               |  NAME       | Identifier                               | 11         |
# | =                              |  OP         | Operator                                 | 11         |
# | price                          |  NAME       | Identifier                               | 11         |
# | -                              |  OP         | Operator                                 | 11         |
# | discount_amount                |  NAME       | Identifier                               | 11         |
# | return                         |  NAME       | Keyword                                  | 12         |
# | discount_amount                |  NAME       | Identifier                               | 12         |
# | ,                              |  OP         |  punctuator                              | 12         |
# | discounted_price               |  NAME       | Identifier                               | 12         |
# |
#                               |  NL         | Other                                    | 13         |
# | # Example usage                |  COMMENT    | Other                                    | 13         |
# |
#                               |  NL         | Other                                    | 13         |
# |                                |  DEDENT     | Other                                    | 13         |
# | price                          |  NAME       | Identifier                               | 13         |
# | =                              |  OP         | Operator                                 | 13         |
# | float                          |  NAME       | Built-in Type or Function                | 13         |
# | (                              |  OP         |  punctuator                              | 13         |
# | input                          |  NAME       | Built-in Type or Function                | 13         |
# | (                              |  OP         |  punctuator                              | 13         |
# | "Enter the original price: "   |  STRING     | String                                   | 13         |
# | )                              |  OP         |  punctuator                              | 13         |
# | )                              |  OP         |  punctuator                              | 13         |
# | discount_percentage            |  NAME       | Identifier                               | 14         |
# | =                              |  OP         | Operator                                 | 14         |
# | float                          |  NAME       | Built-in Type or Function                | 14         |
# | (                              |  OP         |  punctuator                              | 14         |
# | input                          |  NAME       | Built-in Type or Function                | 14         |
# | (                              |  OP         |  punctuator                              | 14         |
# | "Enter the discount percentage: " |  STRING     | String                                   | 14         |
# | )                              |  OP         |  punctuator                              | 14         |
# | )                              |  OP         |  punctuator                              | 14         |
# |
#                               |  NL         | Other                                    | 15         |
# | discount_amount                |  NAME       | Identifier                               | 15         |
# | ,                              |  OP         |  punctuator                              | 15         |
# | discounted_price               |  NAME       | Identifier                               | 15         |
# | =                              |  OP         | Operator                                 | 15         |
# | calculate_discount             |  NAME       | Identifier                               | 15         |
# | (                              |  OP         |  punctuator                              | 15         |
# | price                          |  NAME       | Identifier                               | 15         |
# | ,                              |  OP         |  punctuator                              | 15         |
# | discount_percentage            |  NAME       | Identifier                               | 15         |
# | )                              |  OP         |  punctuator                              | 15         |
# | print                          |  NAME       | Built-in Type or Function                | 16         |
# | (                              |  OP         |  punctuator                              | 16         |
# | "Discount amount: $"           |  STRING     | String                                   | 16         |
# | ,                              |  OP         |  punctuator                              | 16         |
# | discount_amount                |  NAME       | Identifier                               | 16         |
# | )                              |  OP         |  punctuator                              | 16         |
# | print                          |  NAME       | Built-in Type or Function                | 17         |
# | (                              |  OP         |  punctuator                              | 17         |
# | "Discounted price: $"          |  STRING     | String                                   | 17         |
# | ,                              |  OP         |  punctuator                              | 17         |
# | discounted_price               |  NAME       | Identifier                               | 17         |
# | )                              |  OP         |  punctuator                              | 17         |
# |
#                               |  NL         | Other                                    | 18         |
# |
#                               |  NL         | Other                                    | 18         |
# | #CHECKING CASE OF CHARACTER    |  COMMENT    | Other                                    | 18         |
# |
#                               |  NL         | Other                                    | 18         |
# |
#                               |  NL         | Other                                    | 18         |
# | def                            |  NAME       | Keyword                                  | 18         |
# | check_case                     |  NAME       | Identifier                               | 18         |
# | (                              |  OP         |  punctuator                              | 18         |
# | char                           |  NAME       | Identifier                               | 18         |
# | )                              |  OP         |  punctuator                              | 18         |
# | :                              |  OP         |  punctuator                              | 18         |
# |                                |  INDENT     | Other                                    | 19         |
# | if                             |  NAME       | Keyword                                  | 19         |
# | char                           |  NAME       | Identifier                               | 19         |
# | .                              |  OP         |  punctuator                              | 19         |
# | isupper                        |  NAME       | Identifier                               | 19         |
# | (                              |  OP         |  punctuator                              | 19         |
# | )                              |  OP         |  punctuator                              | 19         |
# | :                              |  OP         |  punctuator                              | 19         |
# |                                |  INDENT     | Other                                    | 20         |
# | print                          |  NAME       | Built-in Type or Function                | 20         |
# | (                              |  OP         |  punctuator                              | 20         |
# | f"The character '{char}' is in uppercase." |  STRING     | String                                   | 20         |
# | )                              |  OP         |  punctuator                              | 20         |
# |                                |  DEDENT     | Other                                    | 21         |
# | elif                           |  NAME       | Keyword                                  | 21         |
# | char                           |  NAME       | Identifier                               | 21         |
# | .                              |  OP         |  punctuator                              | 21         |
# | islower                        |  NAME       | Identifier                               | 21         |
# | (                              |  OP         |  punctuator                              | 21         |
# | )                              |  OP         |  punctuator                              | 21         |
# | :                              |  OP         |  punctuator                              | 21         |
# |                                |  INDENT     | Other                                    | 22         |
# | print                          |  NAME       | Built-in Type or Function                | 22         |
# | (                              |  OP         |  punctuator                              | 22         |
# | f"The character '{char}' is in lowercase." |  STRING     | String                                   | 22         |
# | )                              |  OP         |  punctuator                              | 22         |
# |                                |  DEDENT     | Other                                    | 23         |
# | else                           |  NAME       | Keyword                                  | 23         |
# | :                              |  OP         |  punctuator                              | 23         |
# |                                |  INDENT     | Other                                    | 24         |
# | print                          |  NAME       | Built-in Type or Function                | 24         |
# | (                              |  OP         |  punctuator                              | 24         |
# | f"The character '{char}' is neither uppercase nor lowercase." |  STRING     | String                                   | 24         |
# | )                              |  OP         |  punctuator                              | 24         |
# |
#                               |  NL         | Other                                    | 25         |
# | # Example usage                |  COMMENT    | Other                                    | 25         |
# |
#                               |  NL         | Other                                    | 25         |
# |                                |  DEDENT     | Other                                    | 25         |
# |                                |  DEDENT     | Other                                    | 25         |
# | char                           |  NAME       | Identifier                               | 25         |
# | =                              |  OP         | Operator                                 | 25         |
# | input                          |  NAME       | Built-in Type or Function                | 25         |
# | (                              |  OP         |  punctuator                              | 25         |
# | "Enter a character: "          |  STRING     | String                                   | 25         |
# | )                              |  OP         |  punctuator                              | 25         |
# | if                             |  NAME       | Keyword                                  | 26         |
# | len                            |  NAME       | Built-in Type or Function                | 26         |
# | (                              |  OP         |  punctuator                              | 26         |
# | char                           |  NAME       | Identifier                               | 26         |
# | )                              |  OP         |  punctuator                              | 26         |
# | ==                             |  OP         | Operator                                 | 26         |
# | 1                              |  NUMBER     | Number                                   | 26         |
# | :                              |  OP         |  punctuator                              | 26         |
# |                                |  INDENT     | Other                                    | 27         |
# | check_case                     |  NAME       | Identifier                               | 27         |
# | (                              |  OP         |  punctuator                              | 27         |
# | char                           |  NAME       | Identifier                               | 27         |
# | )                              |  OP         |  punctuator                              | 27         |
# |                                |  DEDENT     | Other                                    | 28         |
# | else                           |  NAME       | Keyword                                  | 28         |
# | :                              |  OP         |  punctuator                              | 28         |
# |                                |  INDENT     | Other                                    | 29         |
# | print                          |  NAME       | Built-in Type or Function                | 29         |
# | (                              |  OP         |  punctuator                              | 29         |
# | "Please enter only one character." |  STRING     | String                                   | 29         |
# | )                              |  OP         |  punctuator                              | 29         |
# |
#                               |  NL         | Other                                    | 30         |
# |
#                               |  NL         | Other                                    | 30         |
# |                                |  DEDENT     | Other                                    | 30         |
# |                                |  ENDMARKER  | Other                                    | 30         |
